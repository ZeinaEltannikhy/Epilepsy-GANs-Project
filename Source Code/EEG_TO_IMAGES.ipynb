# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import spectrogram


def process_and_save_txt_file(file_path, output_folder):
    data = np.loadtxt(file_path)

    fs = 178  
    f, t, Sxx = spectrogram(data, fs)

    plt.figure(figsize=(8, 4))
    plt.pcolormesh(t, f, np.log(Sxx + 1e-10), cmap='viridis')
    plt.axis('off') 

    file_name = os.path.splitext(os.path.basename(file_path))[0]
    image_path = os.path.join(output_folder, f'{file_name}_spectrogram.png')
    plt.savefig(image_path, bbox_inches='tight', pad_inches=0)
    plt.close()
    print(f"Saved: {file_name}_spectrogram.png")

main_directory = '/content/drive/MyDrive/Paper/Epileptic-Seizure-Detection-master'

for folder_name in ['A', 'B', 'C', 'D', 'E']:
    folder_path = os.path.join(main_directory, folder_name)
    output_folder = os.path.join(main_directory, f'{folder_name}_images')
    os.makedirs(output_folder, exist_ok=True)

    for filename in os.listdir(folder_path):
        if folder_name == 'C' and filename.endswith('.TXT'): 
            file_path = os.path.join(folder_path, filename)
            process_and_save_txt_file(file_path, output_folder)
            print(f"Processed: {filename}")
        elif filename.endswith('.txt'):  
            file_path = os.path.join(folder_path, filename)
            process_and_save_txt_file(file_path, output_folder)
            print(f"Processed: {filename}")

    print(f"Folder {folder_name} processed. Images saved in: {output_folder}")
# Out:
# Saved: Z087_spectrogram.png
# Processed: Z087.txt
# Saved: Z059_spectrogram.png
# Processed: Z059.txt
# Saved: Z086_spectrogram.png
# Processed: Z086.txt
# Saved: Z084_spectrogram.png
# Processed: Z084.txt
# Saved: Z081_spectrogram.png
# Processed: Z081.txt
# Saved: Z028_spectrogram.png
# Processed: Z028.txt
# Saved: Z007_spectrogram.png
# Processed: Z007.txt
# Saved: Z074_spectrogram.png
# Processed: Z074.txt
# Saved: Z067_spectrogram.png
# Processed: Z067.txt
# Saved: Z021_spectrogram.png
# Processed: Z021.txt
# Saved: Z001_spectrogram.png
# Processed: Z001.txt
# Saved: Z004_spectrogram.png
# Processed: Z004.txt
# Saved: Z053_spectrogram.png
# Processed: Z053.txt
# Saved: Z002_spectrogram.png
# Processed: Z002.txt
# Saved: Z070_spectrogram.png
# Processed: Z070.txt
# Saved: Z035_spectrogram.png
# Processed: Z035.txt
# Saved: Z065_spectrogram.png
# Processed: Z065.txt
# Saved: Z019_spectrogram.png
# Processed: Z019.txt
# Saved: Z037_spectrogram.png
# Processed: Z037.txt
# Saved: Z078_spectrogram.png
# Processed: Z078.txt
# Saved: Z093_spectrogram.png
# Processed: Z093.txt
# Saved: Z017_spectrogram.png
# Processed: Z017.txt
# Saved: Z027_spectrogram.png
# Processed: Z027.txt
# Saved: Z029_spectrogram.png
# Processed: Z029.txt
# Saved: Z014_spectrogram.png
# Processed: Z014.txt
# Saved: Z088_spectrogram.png
# Processed: Z088.txt
# Saved: Z033_spectrogram.png
# Processed: Z033.txt
# Saved: Z011_spectrogram.png
# Processed: Z011.txt
# Saved: Z016_spectrogram.png
# Processed: Z016.txt
# Saved: Z099_spectrogram.png
# Processed: Z099.txt
# Saved: Z073_spectrogram.png
# Processed: Z073.txt
# Saved: Z042_spectrogram.png
# Processed: Z042.txt
# Saved: Z054_spectrogram.png
# Processed: Z054.txt
# Saved: Z023_spectrogram.png
# Processed: Z023.txt
# Saved: Z013_spectrogram.png
# Processed: Z013.txt
# Saved: Z075_spectrogram.png
# Processed: Z075.txt
# Saved: Z100_spectrogram.png
# Processed: Z100.txt
# Saved: Z062_spectrogram.png
# Processed: Z062.txt
# Saved: Z066_spectrogram.png
# Processed: Z066.txt
# Saved: Z044_spectrogram.png
# Processed: Z044.txt
# Saved: Z072_spectrogram.png
# Processed: Z072.txt
# Saved: Z064_spectrogram.png
# Processed: Z064.txt
# Saved: Z046_spectrogram.png
# Processed: Z046.txt
# Saved: Z026_spectrogram.png
# Processed: Z026.txt
# Saved: Z034_spectrogram.png
# Processed: Z034.txt
# Saved: Z030_spectrogram.png
# Processed: Z030.txt
# Saved: Z063_spectrogram.png
# Processed: Z063.txt
# Saved: Z085_spectrogram.png
# Processed: Z085.txt
# Saved: Z079_spectrogram.png
# Processed: Z079.txt
# Saved: Z068_spectrogram.png
# Processed: Z068.txt
# Saved: Z083_spectrogram.png
# Processed: Z083.txt
# Saved: Z012_spectrogram.png
# Processed: Z012.txt
# Saved: Z003_spectrogram.png
# Processed: Z003.txt
# Saved: Z097_spectrogram.png
# Processed: Z097.txt
# Saved: Z006_spectrogram.png
# Processed: Z006.txt
# Saved: Z045_spectrogram.png
# Processed: Z045.txt
# Saved: Z071_spectrogram.png
# Processed: Z071.txt
# Saved: Z096_spectrogram.png
# Processed: Z096.txt
# Saved: Z051_spectrogram.png
# Processed: Z051.txt
# Saved: Z056_spectrogram.png
# Processed: Z056.txt
# Saved: Z055_spectrogram.png
# Processed: Z055.txt
# Saved: Z082_spectrogram.png
# Processed: Z082.txt
# Saved: Z095_spectrogram.png
# Processed: Z095.txt
# Saved: Z076_spectrogram.png
# Processed: Z076.txt
# Saved: Z080_spectrogram.png
# Processed: Z080.txt
# Saved: Z058_spectrogram.png
# Processed: Z058.txt
# Saved: Z039_spectrogram.png
# Processed: Z039.txt
# Saved: Z090_spectrogram.png
# Processed: Z090.txt
# Saved: Z036_spectrogram.png
# Processed: Z036.txt
# Saved: Z031_spectrogram.png
# Processed: Z031.txt
# Saved: Z041_spectrogram.png
# Processed: Z041.txt
# Saved: Z060_spectrogram.png
# Processed: Z060.txt
# Saved: Z069_spectrogram.png
# Processed: Z069.txt
# Saved: Z025_spectrogram.png
# Processed: Z025.txt
# Saved: Z048_spectrogram.png
# Processed: Z048.txt
# Saved: Z098_spectrogram.png
# Processed: Z098.txt
# Saved: Z089_spectrogram.png
# Processed: Z089.txt
# Saved: Z018_spectrogram.png
# Processed: Z018.txt
# Saved: Z020_spectrogram.png
# Processed: Z020.txt
# Saved: Z094_spectrogram.png
# Processed: Z094.txt
# Saved: Z015_spectrogram.png
# Processed: Z015.txt
# Saved: Z010_spectrogram.png
# Processed: Z010.txt
# Saved: Z032_spectrogram.png
# Processed: Z032.txt
# Saved: Z009_spectrogram.png
# Processed: Z009.txt
# Saved: Z077_spectrogram.png
# Processed: Z077.txt
# Saved: Z005_spectrogram.png
# Processed: Z005.txt
# Saved: Z061_spectrogram.png
# Processed: Z061.txt
# Saved: Z040_spectrogram.png
# Processed: Z040.txt
# Saved: Z092_spectrogram.png
# Processed: Z092.txt
# Saved: Z024_spectrogram.png
# Processed: Z024.txt
# Saved: Z047_spectrogram.png
# Processed: Z047.txt
# Saved: Z022_spectrogram.png
# Processed: Z022.txt
# Saved: Z043_spectrogram.png
# Processed: Z043.txt
# Saved: Z052_spectrogram.png
# Processed: Z052.txt
# Saved: Z038_spectrogram.png
# Processed: Z038.txt
# Saved: Z049_spectrogram.png
# Processed: Z049.txt
# Saved: Z008_spectrogram.png
# Processed: Z008.txt
# Saved: Z057_spectrogram.png
# Processed: Z057.txt
# Saved: Z091_spectrogram.png
# Processed: Z091.txt
# Saved: Z050_spectrogram.png
# Processed: Z050.txt
# Folder A processed. Images saved in: /content/drive/MyDrive/Paper/Epileptic-Seizure-Detection-master/A_images
# Saved: O008_spectrogram.png
# Processed: O008.txt
# Saved: O073_spectrogram.png
# Processed: O073.txt
# Saved: O083_spectrogram.png
# Processed: O083.txt
# Saved: O043_spectrogram.png
# Processed: O043.txt
# Saved: O058_spectrogram.png
# Processed: O058.txt
# Saved: O087_spectrogram.png
# Processed: O087.txt
# Saved: O079_spectrogram.png
# Processed: O079.txt
# Saved: O051_spectrogram.png
# Processed: O051.txt
# Saved: O097_spectrogram.png
# Processed: O097.txt
# Saved: O081_spectrogram.png
# Processed: O081.txt
# Saved: O064_spectrogram.png
# Processed: O064.txt
# Saved: O020_spectrogram.png
# Processed: O020.txt
# Saved: O089_spectrogram.png
# Processed: O089.txt
# Saved: O074_spectrogram.png
# Processed: O074.txt
# Saved: O003_spectrogram.png
# Processed: O003.txt
# Saved: O096_spectrogram.png
# Processed: O096.txt
# Saved: O062_spectrogram.png
# Processed: O062.txt
# Saved: O031_spectrogram.png
# Processed: O031.txt
# Saved: O042_spectrogram.png
# Processed: O042.txt
# Saved: O059_spectrogram.png
# Processed: O059.txt
# Saved: O049_spectrogram.png
# Processed: O049.txt
# Saved: O040_spectrogram.png
# Processed: O040.txt
# Saved: O028_spectrogram.png
# Processed: O028.txt
# Saved: O070_spectrogram.png
# Processed: O070.txt
# Saved: O047_spectrogram.png
# Processed: O047.txt
# Saved: O023_spectrogram.png
# Processed: O023.txt
# Saved: O088_spectrogram.png
# Processed: O088.txt
# Saved: O009_spectrogram.png
# Processed: O009.txt
# Saved: O098_spectrogram.png
# Processed: O098.txt
# Saved: O052_spectrogram.png
# Processed: O052.txt
# Saved: O037_spectrogram.png
# Processed: O037.txt
# Saved: O034_spectrogram.png
# Processed: O034.txt
# Saved: O025_spectrogram.png
# Processed: O025.txt
# Saved: O082_spectrogram.png
# Processed: O082.txt
# Saved: O072_spectrogram.png
# Processed: O072.txt
# Saved: O090_spectrogram.png
# Processed: O090.txt
# Saved: O055_spectrogram.png
# Processed: O055.txt
# Saved: O067_spectrogram.png
# Processed: O067.txt
# Saved: O012_spectrogram.png
# Processed: O012.txt
# Saved: O035_spectrogram.png
# Processed: O035.txt
# Saved: O077_spectrogram.png
# Processed: O077.txt
# Saved: O005_spectrogram.png
# Processed: O005.txt
# Saved: O076_spectrogram.png
# Processed: O076.txt
# Saved: O030_spectrogram.png
# Processed: O030.txt
# Saved: O015_spectrogram.png
# Processed: O015.txt
# Saved: O002_spectrogram.png
# Processed: O002.txt
# Saved: O085_spectrogram.png
# Processed: O085.txt
# Saved: O069_spectrogram.png
# Processed: O069.txt
# Saved: O050_spectrogram.png
# Processed: O050.txt
# Saved: O057_spectrogram.png
# Processed: O057.txt
# Saved: O099_spectrogram.png
# Processed: O099.txt
# Saved: O032_spectrogram.png
# Processed: O032.txt
# Saved: O016_spectrogram.png
# Processed: O016.txt
# Saved: O017_spectrogram.png
# Processed: O017.txt
# Saved: O004_spectrogram.png
# Processed: O004.txt
# Saved: O048_spectrogram.png
# Processed: O048.txt
# Saved: O075_spectrogram.png
# Processed: O075.txt
# Saved: O054_spectrogram.png
# Processed: O054.txt
# Saved: O066_spectrogram.png
# Processed: O066.txt
# Saved: O011_spectrogram.png
# Processed: O011.txt
# Saved: O078_spectrogram.png
# Processed: O078.txt
# Saved: O018_spectrogram.png
# Processed: O018.txt
# Saved: O027_spectrogram.png
# Processed: O027.txt
# Saved: O024_spectrogram.png
# Processed: O024.txt
# Saved: O060_spectrogram.png
# Processed: O060.txt
# Saved: O021_spectrogram.png
# Processed: O021.txt
# Saved: O065_spectrogram.png
# Processed: O065.txt
# Saved: O092_spectrogram.png
# Processed: O092.txt
# Saved: O026_spectrogram.png
# Processed: O026.txt
# Saved: O041_spectrogram.png
# Processed: O041.txt
# Saved: O094_spectrogram.png
# Processed: O094.txt
# Saved: O022_spectrogram.png
# Processed: O022.txt
# Saved: O013_spectrogram.png
# Processed: O013.txt
# Saved: O086_spectrogram.png
# Processed: O086.txt
# Saved: O091_spectrogram.png
# Processed: O091.txt
# Saved: O095_spectrogram.png
# Processed: O095.txt
# Saved: O046_spectrogram.png
# Processed: O046.txt
# Saved: O006_spectrogram.png
# Processed: O006.txt
# Saved: O045_spectrogram.png
# Processed: O045.txt
# Saved: O080_spectrogram.png
# Processed: O080.txt
# Saved: O036_spectrogram.png
# Processed: O036.txt
# Saved: O010_spectrogram.png
# Processed: O010.txt
# Saved: O084_spectrogram.png
# Processed: O084.txt
# Saved: O100_spectrogram.png
# Processed: O100.txt
# Saved: O029_spectrogram.png
# Processed: O029.txt
# Saved: O019_spectrogram.png
# Processed: O019.txt
# Saved: O014_spectrogram.png
# Processed: O014.txt
# Saved: O039_spectrogram.png
# Processed: O039.txt
# Saved: O093_spectrogram.png
# Processed: O093.txt
# Saved: O044_spectrogram.png
# Processed: O044.txt
# Saved: O063_spectrogram.png
# Processed: O063.txt
# Saved: O001_spectrogram.png
# Processed: O001.txt
# Saved: O056_spectrogram.png
# Processed: O056.txt
# Saved: O061_spectrogram.png
# Processed: O061.txt
# Saved: O007_spectrogram.png
# Processed: O007.txt
# Saved: O038_spectrogram.png
# Processed: O038.txt
# Saved: O071_spectrogram.png
# Processed: O071.txt
# Saved: O053_spectrogram.png
# Processed: O053.txt
# Saved: O068_spectrogram.png
# Processed: O068.txt
# Saved: O033_spectrogram.png
# Processed: O033.txt
# Folder B processed. Images saved in: /content/drive/MyDrive/Paper/Epileptic-Seizure-Detection-master/B_images
# Saved: N071_spectrogram.png
# Processed: N071.TXT
# Saved: N088_spectrogram.png
# Processed: N088.TXT
# Saved: N031_spectrogram.png
# Processed: N031.TXT
# Saved: N074_spectrogram.png
# Processed: N074.TXT
# Saved: N040_spectrogram.png
# Processed: N040.TXT
# Saved: N047_spectrogram.png
# Processed: N047.TXT
# Saved: N072_spectrogram.png
# Processed: N072.TXT
# Saved: N069_spectrogram.png
# Processed: N069.TXT
# Saved: N081_spectrogram.png
# Processed: N081.TXT
# Saved: N089_spectrogram.png
# Processed: N089.TXT
# Saved: N077_spectrogram.png
# Processed: N077.TXT
# Saved: N075_spectrogram.png
# Processed: N075.TXT
# Saved: N059_spectrogram.png
# Processed: N059.TXT
# Saved: N095_spectrogram.png
# Processed: N095.TXT
# Saved: N056_spectrogram.png
# Processed: N056.TXT
# Saved: N043_spectrogram.png
# Processed: N043.TXT
# Saved: N080_spectrogram.png
# Processed: N080.TXT
# Saved: N073_spectrogram.png
# Processed: N073.TXT
# Saved: N097_spectrogram.png
# Processed: N097.TXT
# Saved: N052_spectrogram.png
# Processed: N052.TXT
# Saved: N083_spectrogram.png
# Processed: N083.TXT
# Saved: N010_spectrogram.png
# Processed: N010.TXT
# Saved: N070_spectrogram.png
# Processed: N070.TXT
# Saved: N024_spectrogram.png
# Processed: N024.TXT
# Saved: N066_spectrogram.png
# Processed: N066.TXT
# Saved: N023_spectrogram.png
# Processed: N023.TXT
# Saved: N051_spectrogram.png
# Processed: N051.TXT
# Saved: N098_spectrogram.png
# Processed: N098.TXT
# Saved: N011_spectrogram.png
# Processed: N011.TXT
# Saved: N028_spectrogram.png
# Processed: N028.TXT
# Saved: N068_spectrogram.png
# Processed: N068.TXT
# Saved: N064_spectrogram.png
# Processed: N064.TXT
# Saved: N065_spectrogram.png
# Processed: N065.TXT
# Saved: N046_spectrogram.png
# Processed: N046.TXT
# Saved: N057_spectrogram.png
# Processed: N057.TXT
# Saved: N013_spectrogram.png
# Processed: N013.TXT
# Saved: N008_spectrogram.png
# Processed: N008.TXT
# Saved: N092_spectrogram.png
# Processed: N092.TXT
# Saved: N063_spectrogram.png
# Processed: N063.TXT
# Saved: N067_spectrogram.png
# Processed: N067.TXT
# Saved: N022_spectrogram.png
# Processed: N022.TXT
# Saved: N079_spectrogram.png
# Processed: N079.TXT
# Saved: N035_spectrogram.png
# Processed: N035.TXT
# Saved: N038_spectrogram.png
# Processed: N038.TXT
# Saved: N001_spectrogram.png
# Processed: N001.TXT
# Saved: N006_spectrogram.png
# Processed: N006.TXT
# Saved: N005_spectrogram.png
# Processed: N005.TXT
# Saved: N044_spectrogram.png
# Processed: N044.TXT
# Saved: N015_spectrogram.png
# Processed: N015.TXT
# Saved: N091_spectrogram.png
# Processed: N091.TXT
# Saved: N084_spectrogram.png
# Processed: N084.TXT
# Saved: N002_spectrogram.png
# Processed: N002.TXT
# Saved: N058_spectrogram.png
# Processed: N058.TXT
# Saved: N093_spectrogram.png
# Processed: N093.TXT
# Saved: N039_spectrogram.png
# Processed: N039.TXT
# Saved: N020_spectrogram.png
# Processed: N020.TXT
# Saved: N018_spectrogram.png
# Processed: N018.TXT
# Saved: N014_spectrogram.png
# Processed: N014.TXT
# Saved: N087_spectrogram.png
# Processed: N087.TXT
# Saved: N026_spectrogram.png
# Processed: N026.TXT
# Saved: N086_spectrogram.png
# Processed: N086.TXT
# Saved: N017_spectrogram.png
# Processed: N017.TXT
# Saved: N062_spectrogram.png
# Processed: N062.TXT
# Saved: N078_spectrogram.png
# Processed: N078.TXT
# Saved: N094_spectrogram.png
# Processed: N094.TXT
# Saved: N033_spectrogram.png
# Processed: N033.TXT
# Saved: N016_spectrogram.png
# Processed: N016.TXT
# Saved: N007_spectrogram.png
# Processed: N007.TXT
# Saved: N100_spectrogram.png
# Processed: N100.TXT
# Saved: N090_spectrogram.png
# Processed: N090.TXT
# Saved: N076_spectrogram.png
# Processed: N076.TXT
# Saved: N012_spectrogram.png
# Processed: N012.TXT
# Saved: N027_spectrogram.png
# Processed: N027.TXT
# Saved: N032_spectrogram.png
# Processed: N032.TXT
# Saved: N061_spectrogram.png
# Processed: N061.TXT
# Saved: N045_spectrogram.png
# Processed: N045.TXT
# Saved: N041_spectrogram.png
# Processed: N041.TXT
# Saved: N054_spectrogram.png
# Processed: N054.TXT
# Saved: N085_spectrogram.png
# Processed: N085.TXT
# Saved: N029_spectrogram.png
# Processed: N029.TXT
# Saved: N036_spectrogram.png
# Processed: N036.TXT
# Saved: N034_spectrogram.png
# Processed: N034.TXT
# Saved: N003_spectrogram.png
# Processed: N003.TXT
# Saved: N009_spectrogram.png
# Processed: N009.TXT
# Saved: N030_spectrogram.png
# Processed: N030.TXT
# Saved: N050_spectrogram.png
# Processed: N050.TXT
# Saved: N021_spectrogram.png
# Processed: N021.TXT
# Saved: N096_spectrogram.png
# Processed: N096.TXT
# Saved: N082_spectrogram.png
# Processed: N082.TXT
# Saved: N019_spectrogram.png
# Processed: N019.TXT
# Saved: N025_spectrogram.png
# Processed: N025.TXT
# Saved: N099_spectrogram.png
# Processed: N099.TXT
# Saved: N049_spectrogram.png
# Processed: N049.TXT
# Saved: N042_spectrogram.png
# Processed: N042.TXT
# Saved: N004_spectrogram.png
# Processed: N004.TXT
# Saved: N048_spectrogram.png
# Processed: N048.TXT
# Saved: N060_spectrogram.png
# Processed: N060.TXT
# Saved: N037_spectrogram.png
# Processed: N037.TXT
# Saved: N053_spectrogram.png
# Processed: N053.TXT
# Saved: N055_spectrogram.png
# Processed: N055.TXT
# Folder C processed. Images saved in: /content/drive/MyDrive/Paper/Epileptic-Seizure-Detection-master/C_images
# Saved: F053_spectrogram.png
# Processed: F053.txt
# Saved: F095_spectrogram.png
# Processed: F095.txt
# Saved: F083_spectrogram.png
# Processed: F083.txt
# Saved: F034_spectrogram.png
# Processed: F034.txt
# Saved: F091_spectrogram.png
# Processed: F091.txt
# Saved: F008_spectrogram.png
# Processed: F008.txt
# Saved: F002_spectrogram.png
# Processed: F002.txt
# Saved: F048_spectrogram.png
# Processed: F048.txt
# Saved: F092_spectrogram.png
# Processed: F092.txt
# Saved: F100_spectrogram.png
# Processed: F100.txt
# Saved: F078_spectrogram.png
# Processed: F078.txt
# Saved: F085_spectrogram.png
# Processed: F085.txt
# Saved: F088_spectrogram.png
# Processed: F088.txt
# Saved: F056_spectrogram.png
# Processed: F056.txt
# Saved: F099_spectrogram.png
# Processed: F099.txt
# Saved: F059_spectrogram.png
# Processed: F059.txt
# Saved: F018_spectrogram.png
# Processed: F018.txt
# Saved: F063_spectrogram.png
# Processed: F063.txt
# Saved: F094_spectrogram.png
# Processed: F094.txt
# Saved: F047_spectrogram.png
# Processed: F047.txt
# Saved: F039_spectrogram.png
# Processed: F039.txt
# Saved: F020_spectrogram.png
# Processed: F020.txt
# Saved: F016_spectrogram.png
# Processed: F016.txt
# Saved: F058_spectrogram.png
# Processed: F058.txt
# Saved: F026_spectrogram.png
# Processed: F026.txt
# Saved: F077_spectrogram.png
# Processed: F077.txt
# Saved: F025_spectrogram.png
# Processed: F025.txt
# Saved: F029_spectrogram.png
# Processed: F029.txt
# Saved: F054_spectrogram.png
# Processed: F054.txt
# Saved: F060_spectrogram.png
# Processed: F060.txt
# Saved: F014_spectrogram.png
# Processed: F014.txt
# Saved: F001_spectrogram.png
# Processed: F001.txt
# Saved: F062_spectrogram.png
# Processed: F062.txt
# Saved: F075_spectrogram.png
# Processed: F075.txt
# Saved: F086_spectrogram.png
# Processed: F086.txt
# Saved: F097_spectrogram.png
# Processed: F097.txt
# Saved: F032_spectrogram.png
# Processed: F032.txt
# Saved: F081_spectrogram.png
# Processed: F081.txt
# Saved: F074_spectrogram.png
# Processed: F074.txt
# Saved: F027_spectrogram.png
# Processed: F027.txt
# Saved: F072_spectrogram.png
# Processed: F072.txt
# Saved: F079_spectrogram.png
# Processed: F079.txt
# Saved: F073_spectrogram.png
# Processed: F073.txt
# Saved: F066_spectrogram.png
# Processed: F066.txt
# Saved: F049_spectrogram.png
# Processed: F049.txt
# Saved: F068_spectrogram.png
# Processed: F068.txt
# Saved: F007_spectrogram.png
# Processed: F007.txt
# Saved: F006_spectrogram.png
# Processed: F006.txt
# Saved: F098_spectrogram.png
# Processed: F098.txt
# Saved: F055_spectrogram.png
# Processed: F055.txt
# Saved: F024_spectrogram.png
# Processed: F024.txt
# Saved: F031_spectrogram.png
# Processed: F031.txt
# Saved: F061_spectrogram.png
# Processed: F061.txt
# Saved: F080_spectrogram.png
# Processed: F080.txt
# Saved: F011_spectrogram.png
# Processed: F011.txt
# Saved: F057_spectrogram.png
# Processed: F057.txt
# Saved: F042_spectrogram.png
# Processed: F042.txt
# Saved: F090_spectrogram.png
# Processed: F090.txt
# Saved: F065_spectrogram.png
# Processed: F065.txt
# Saved: F043_spectrogram.png
# Processed: F043.txt
# Saved: F040_spectrogram.png
# Processed: F040.txt
# Saved: F036_spectrogram.png
# Processed: F036.txt
# Saved: F017_spectrogram.png
# Processed: F017.txt
# Saved: F084_spectrogram.png
# Processed: F084.txt
# Saved: F052_spectrogram.png
# Processed: F052.txt
# Saved: F022_spectrogram.png
# Processed: F022.txt
# Saved: F012_spectrogram.png
# Processed: F012.txt
# Saved: F045_spectrogram.png
# Processed: F045.txt
# Saved: F041_spectrogram.png
# Processed: F041.txt
# Saved: F076_spectrogram.png
# Processed: F076.txt
# Saved: F050_spectrogram.png
# Processed: F050.txt
# Saved: F064_spectrogram.png
# Processed: F064.txt
# Saved: F087_spectrogram.png
# Processed: F087.txt
# Saved: F035_spectrogram.png
# Processed: F035.txt
# Saved: F009_spectrogram.png
# Processed: F009.txt
# Saved: F093_spectrogram.png
# Processed: F093.txt
# Saved: F069_spectrogram.png
# Processed: F069.txt
# Saved: F082_spectrogram.png
# Processed: F082.txt
# Saved: F019_spectrogram.png
# Processed: F019.txt
# Saved: F037_spectrogram.png
# Processed: F037.txt
# Saved: F021_spectrogram.png
# Processed: F021.txt
# Saved: F071_spectrogram.png
# Processed: F071.txt
# Saved: F015_spectrogram.png
# Processed: F015.txt
# Saved: F005_spectrogram.png
# Processed: F005.txt
# Saved: F046_spectrogram.png
# Processed: F046.txt
# Saved: F004_spectrogram.png
# Processed: F004.txt
# Saved: F096_spectrogram.png
# Processed: F096.txt
# Saved: F044_spectrogram.png
# Processed: F044.txt
# Saved: F089_spectrogram.png
# Processed: F089.txt
# Saved: F030_spectrogram.png
# Processed: F030.txt
# Saved: F038_spectrogram.png
# Processed: F038.txt
# Saved: F070_spectrogram.png
# Processed: F070.txt
# Saved: F013_spectrogram.png
# Processed: F013.txt
# Saved: F028_spectrogram.png
# Processed: F028.txt
# Saved: F051_spectrogram.png
# Processed: F051.txt
# Saved: F033_spectrogram.png
# Processed: F033.txt
# Saved: F067_spectrogram.png
# Processed: F067.txt
# Saved: F010_spectrogram.png
# Processed: F010.txt
# Saved: F003_spectrogram.png
# Processed: F003.txt
# Saved: F023_spectrogram.png
# Processed: F023.txt
# Folder D processed. Images saved in: /content/drive/MyDrive/Paper/Epileptic-Seizure-Detection-master/D_images
# Saved: S027_spectrogram.png
# Processed: S027.txt
# Saved: S050_spectrogram.png
# Processed: S050.txt
# Saved: S085_spectrogram.png
# Processed: S085.txt
# Saved: S077_spectrogram.png
# Processed: S077.txt
# Saved: S072_spectrogram.png
# Processed: S072.txt
# Saved: S004_spectrogram.png
# Processed: S004.txt
# Saved: S098_spectrogram.png
# Processed: S098.txt
# Saved: S006_spectrogram.png
# Processed: S006.txt
# Saved: S086_spectrogram.png
# Processed: S086.txt
# Saved: S089_spectrogram.png
# Processed: S089.txt
# Saved: S066_spectrogram.png
# Processed: S066.txt
# Saved: S034_spectrogram.png
# Processed: S034.txt
# Saved: S020_spectrogram.png
# Processed: S020.txt
# Saved: S076_spectrogram.png
# Processed: S076.txt
# Saved: S092_spectrogram.png
# Processed: S092.txt
# Saved: S007_spectrogram.png
# Processed: S007.txt
# Saved: S040_spectrogram.png
# Processed: S040.txt
# Saved: S082_spectrogram.png
# Processed: S082.txt
# Saved: S100_spectrogram.png
# Processed: S100.txt
# Saved: S074_spectrogram.png
# Processed: S074.txt
# Saved: S065_spectrogram.png
# Processed: S065.txt
# Saved: S059_spectrogram.png
# Processed: S059.txt
# Saved: S058_spectrogram.png
# Processed: S058.txt
# Saved: S016_spectrogram.png
# Processed: S016.txt
# Saved: S003_spectrogram.png
# Processed: S003.txt
# Saved: S095_spectrogram.png
# Processed: S095.txt
# Saved: S061_spectrogram.png
# Processed: S061.txt
# Saved: S019_spectrogram.png
# Processed: S019.txt
# Saved: S025_spectrogram.png
# Processed: S025.txt
# Saved: S017_spectrogram.png
# Processed: S017.txt
# Saved: S070_spectrogram.png
# Processed: S070.txt
# Saved: S021_spectrogram.png
# Processed: S021.txt
# Saved: S028_spectrogram.png
# Processed: S028.txt
# Saved: S026_spectrogram.png
# Processed: S026.txt
# Saved: S084_spectrogram.png
# Processed: S084.txt
# Saved: S048_spectrogram.png
# Processed: S048.txt
# Saved: S080_spectrogram.png
# Processed: S080.txt
# Saved: S054_spectrogram.png
# Processed: S054.txt
# Saved: S032_spectrogram.png
# Processed: S032.txt
# Saved: S036_spectrogram.png
# Processed: S036.txt
# Saved: S039_spectrogram.png
# Processed: S039.txt
# Saved: S097_spectrogram.png
# Processed: S097.txt
# Saved: S056_spectrogram.png
# Processed: S056.txt
# Saved: S094_spectrogram.png
# Processed: S094.txt
# Saved: S030_spectrogram.png
# Processed: S030.txt
# Saved: S057_spectrogram.png
# Processed: S057.txt
# Saved: S075_spectrogram.png
# Processed: S075.txt
# Saved: S043_spectrogram.png
# Processed: S043.txt
# Saved: S067_spectrogram.png
# Processed: S067.txt
# Saved: S044_spectrogram.png
# Processed: S044.txt
# Saved: S047_spectrogram.png
# Processed: S047.txt
# Saved: S078_spectrogram.png
# Processed: S078.txt
# Saved: S001_spectrogram.png
# Processed: S001.txt
# Saved: S099_spectrogram.png
# Processed: S099.txt
# Saved: S096_spectrogram.png
# Processed: S096.txt
# Saved: S042_spectrogram.png
# Processed: S042.txt
# Saved: S063_spectrogram.png
# Processed: S063.txt
# Saved: S009_spectrogram.png
# Processed: S009.txt
# Saved: S068_spectrogram.png
# Processed: S068.txt
# Saved: S064_spectrogram.png
# Processed: S064.txt
# Saved: S022_spectrogram.png
# Processed: S022.txt
# Saved: S013_spectrogram.png
# Processed: S013.txt
# Saved: S035_spectrogram.png
# Processed: S035.txt
# Saved: S024_spectrogram.png
# Processed: S024.txt
# Saved: S010_spectrogram.png
# Processed: S010.txt
# Saved: S008_spectrogram.png
# Processed: S008.txt
# Saved: S081_spectrogram.png
# Processed: S081.txt
# Saved: S071_spectrogram.png
# Processed: S071.txt
# Saved: S079_spectrogram.png
# Processed: S079.txt
# Saved: S083_spectrogram.png
# Processed: S083.txt
# Saved: S073_spectrogram.png
# Processed: S073.txt
# Saved: S023_spectrogram.png
# Processed: S023.txt
# Saved: S041_spectrogram.png
# Processed: S041.txt
# Saved: S031_spectrogram.png
# Processed: S031.txt
# Saved: S055_spectrogram.png
# Processed: S055.txt
# Saved: S029_spectrogram.png
# Processed: S029.txt
# Saved: S093_spectrogram.png
# Processed: S093.txt
# Saved: S090_spectrogram.png
# Processed: S090.txt
# Saved: S033_spectrogram.png
# Processed: S033.txt
# Saved: S060_spectrogram.png
# Processed: S060.txt
# Saved: S088_spectrogram.png
# Processed: S088.txt
# Saved: S051_spectrogram.png
# Processed: S051.txt
# Saved: S015_spectrogram.png
# Processed: S015.txt
# Saved: S062_spectrogram.png
# Processed: S062.txt
# Saved: S049_spectrogram.png
# Processed: S049.txt
# Saved: S091_spectrogram.png
# Processed: S091.txt
# Saved: S038_spectrogram.png
# Processed: S038.txt
# Saved: S053_spectrogram.png
# Processed: S053.txt
# Saved: S005_spectrogram.png
# Processed: S005.txt
# Saved: S045_spectrogram.png
# Processed: S045.txt
# Saved: S002_spectrogram.png
# Processed: S002.txt
# Saved: S011_spectrogram.png
# Processed: S011.txt
# Saved: S037_spectrogram.png
# Processed: S037.txt
# Saved: S012_spectrogram.png
# Processed: S012.txt
# Saved: S069_spectrogram.png
# Processed: S069.txt
# Saved: S087_spectrogram.png
# Processed: S087.txt
# Saved: S018_spectrogram.png
# Processed: S018.txt
# Saved: S052_spectrogram.png
# Processed: S052.txt
# Saved: S046_spectrogram.png
# Processed: S046.txt
# Saved: S014_spectrogram.png
# Processed: S014.txt
# Folder E processed. Images saved in: /content/drive/MyDrive/Paper/Epileptic-Seizure-Detection-master/E_images

# %% [markdown]
# Three Classes

# %%
import os
import shutil


main_directory = '/content/drive/MyDrive/Paper/Epileptic-Seizure-Detection-master/Images/Three-Classes'
image_folders = {
    'healthy': ['A_images', 'B_images'],
    'pre-ictal': ['C_images', 'D_images'],
    'epilepsy': ['E_images']
}

merged_dir = os.path.join(main_directory, 'Merged')
os.makedirs(merged_dir, exist_ok=True)

for category, folders in image_folders.items():
    category_dir = os.path.join(merged_dir, category)
    os.makedirs(category_dir, exist_ok=True)

    for folder in folders:
        folder_path = os.path.join(main_directory, folder)
        for filename in os.listdir(folder_path):
            if filename.endswith('.png'):
                file_path = os.path.join(folder_path, filename)
                shutil.copy(file_path, os.path.join(category_dir, filename))
                print(f"Copied: {filename} to {category}")

print("Images merged into categories successfully.")
# Out:
# Copied: Z050_spectrogram.png to healthy
# Copied: Z010_spectrogram.png to healthy
# Copied: Z017_spectrogram.png to healthy
# Copied: Z057_spectrogram.png to healthy
# Copied: Z073_spectrogram.png to healthy
# Copied: Z009_spectrogram.png to healthy
# Copied: Z006_spectrogram.png to healthy
# Copied: Z041_spectrogram.png to healthy
# Copied: Z034_spectrogram.png to healthy
# Copied: Z092_spectrogram.png to healthy
# Copied: Z022_spectrogram.png to healthy
# Copied: Z058_spectrogram.png to healthy
# Copied: Z084_spectrogram.png to healthy
# Copied: Z065_spectrogram.png to healthy
# Copied: Z095_spectrogram.png to healthy
# Copied: Z074_spectrogram.png to healthy
# Copied: Z049_spectrogram.png to healthy
# Copied: Z046_spectrogram.png to healthy
# Copied: Z033_spectrogram.png to healthy
# Copied: Z001_spectrogram.png to healthy
# Copied: Z047_spectrogram.png to healthy
# Copied: Z075_spectrogram.png to healthy
# Copied: Z016_spectrogram.png to healthy
# Copied: Z032_spectrogram.png to healthy
# Copied: Z051_spectrogram.png to healthy
# Copied: Z094_spectrogram.png to healthy
# Copied: Z048_spectrogram.png to healthy
# Copied: Z025_spectrogram.png to healthy
# Copied: Z083_spectrogram.png to healthy
# Copied: Z018_spectrogram.png to healthy
# Copied: Z062_spectrogram.png to healthy
# Copied: Z082_spectrogram.png to healthy
# Copied: Z063_spectrogram.png to healthy
# Copied: Z019_spectrogram.png to healthy
# Copied: Z024_spectrogram.png to healthy
# Copied: Z023_spectrogram.png to healthy
# Copied: Z082_spectrogram (1).png to healthy
# Copied: Z100_spectrogram.png to healthy
# Copied: Z019_spectrogram (1).png to healthy
# Copied: Z063_spectrogram (1).png to healthy
# Copied: Z085_spectrogram.png to healthy
# Copied: Z007_spectrogram.png to healthy
# Copied: Z040_spectrogram.png to healthy
# Copied: Z064_spectrogram.png to healthy
# Copied: Z059_spectrogram.png to healthy
# Copied: Z076_spectrogram.png to healthy
# Copied: Z036_spectrogram.png to healthy
# Copied: Z055_spectrogram.png to healthy
# Copied: Z068_spectrogram.png to healthy
# Copied: Z012_spectrogram.png to healthy
# Copied: Z071_spectrogram.png to healthy
# Copied: Z089_spectrogram.png to healthy
# Copied: Z020_spectrogram.png to healthy
# Copied: Z043_spectrogram.png to healthy
# Copied: Z086_spectrogram.png to healthy
# Copied: Z090_spectrogram.png to healthy
# Copied: Z067_spectrogram.png to healthy
# Copied: Z061_spectrogram.png to healthy
# Copied: Z099_spectrogram.png to healthy
# Copied: Z029_spectrogram.png to healthy
# Copied: Z002_spectrogram.png to healthy
# Copied: Z078_spectrogram.png to healthy
# Copied: Z045_spectrogram.png to healthy
# Copied: Z026_spectrogram.png to healthy
# Copied: Z088_spectrogram.png to healthy
# Copied: Z069_spectrogram.png to healthy
# Copied: Z013_spectrogram.png to healthy
# Copied: Z070_spectrogram.png to healthy
# Copied: Z066_spectrogram.png to healthy
# Copied: Z054_spectrogram.png to healthy
# Copied: Z021_spectrogram.png to healthy
# Copied: Z039_spectrogram.png to healthy
# Copied: Z087_spectrogram.png to healthy
# Copied: Z080_spectrogram.png to healthy
# Copied: Z042_spectrogram.png to healthy
# Copied: Z040_spectrogram (1).png to healthy
# Copied: Z024_spectrogram (1).png to healthy
# Copied: Z056_spectrogram.png to healthy
# Copied: Z035_spectrogram.png to healthy
# Copied: Z011_spectrogram.png to healthy
# Copied: Z096_spectrogram.png to healthy
# Copied: Z030_spectrogram.png to healthy
# Copied: Z008_spectrogram.png to healthy
# Copied: Z072_spectrogram.png to healthy
# Copied: Z014_spectrogram.png to healthy
# Copied: Z053_spectrogram.png to healthy
# Copied: Z059_spectrogram (1).png to healthy
# Copied: Z085_spectrogram (1).png to healthy
# Copied: Z023_spectrogram (1).png to healthy
# Copied: Z064_spectrogram (1).png to healthy
# Copied: Z004_spectrogram.png to healthy
# Copied: Z005_spectrogram.png to healthy
# Copied: Z038_spectrogram.png to healthy
# Copied: Z077_spectrogram.png to healthy
# Copied: Z091_spectrogram.png to healthy
# Copied: Z037_spectrogram.png to healthy
# Copied: Z093_spectrogram.png to healthy
# Copied: Z003_spectrogram.png to healthy
# Copied: Z027_spectrogram.png to healthy
# Copied: Z081_spectrogram.png to healthy
# Copied: Z031_spectrogram.png to healthy
# Copied: Z060_spectrogram.png to healthy
# Copied: Z052_spectrogram.png to healthy
# Copied: Z028_spectrogram.png to healthy
# Copied: Z097_spectrogram.png to healthy
# Copied: Z044_spectrogram.png to healthy
# Copied: Z079_spectrogram.png to healthy
# Copied: Z098_spectrogram.png to healthy
# Copied: Z015_spectrogram.png to healthy
# Copied: O070_spectrogram.png to healthy
# Copied: O042_spectrogram.png to healthy
# Copied: O013_spectrogram.png to healthy
# Copied: O037_spectrogram.png to healthy
# Copied: O088_spectrogram.png to healthy
# Copied: O091_spectrogram.png to healthy
# Copied: O069_spectrogram.png to healthy
# Copied: O029_spectrogram.png to healthy
# Copied: O053_spectrogram.png to healthy
# Copied: O038_spectrogram.png to healthy
# Copied: O005_spectrogram.png to healthy
# Copied: O054_spectrogram.png to healthy
# Copied: O014_spectrogram.png to healthy
# Copied: O077_spectrogram.png to healthy
# Copied: O096_spectrogram.png to healthy
# Copied: O002_spectrogram.png to healthy
# Copied: O045_spectrogram.png to healthy
# Copied: O099_spectrogram.png to healthy
# Copied: O026_spectrogram.png to healthy
# Copied: O061_spectrogram.png to healthy
# Copied: O080_spectrogram.png to healthy
# Copied: O030_spectrogram.png to healthy
# Copied: O078_spectrogram.png to healthy
# Copied: O067_spectrogram.png to healthy
# Copied: O089_spectrogram.png to healthy
# Copied: O098_spectrogram.png to healthy
# Copied: O081_spectrogram.png to healthy
# Copied: O044_spectrogram.png to healthy
# Copied: O079_spectrogram.png to healthy
# Copied: O060_spectrogram.png to healthy
# Copied: O027_spectrogram.png to healthy
# Copied: O097_spectrogram.png to healthy
# Copied: O039_spectrogram.png to healthy
# Copied: O071_spectrogram.png to healthy
# Copied: O031_spectrogram.png to healthy
# Copied: O076_spectrogram.png to healthy
# Copied: O043_spectrogram.png to healthy
# Copied: O004_spectrogram.png to healthy
# Copied: O090_spectrogram.png to healthy
# Copied: O036_spectrogram.png to healthy
# Copied: O068_spectrogram.png to healthy
# Copied: O012_spectrogram.png to healthy
# Copied: O055_spectrogram.png to healthy
# Copied: O028_spectrogram.png to healthy
# Copied: O015_spectrogram.png to healthy
# Copied: O003_spectrogram.png to healthy
# Copied: O020_spectrogram.png to healthy
# Copied: O052_spectrogram.png to healthy
# Copied: O086_spectrogram.png to healthy
# Copied: O074_spectrogram.png to healthy
# Copied: O049_spectrogram.png to healthy
# Copied: O095_spectrogram.png to healthy
# Copied: O050_spectrogram.png to healthy
# Copied: O083_spectrogram.png to healthy
# Copied: O025_spectrogram.png to healthy
# Copied: O062_spectrogram.png to healthy
# Copied: O018_spectrogram.png to healthy
# Copied: O001_spectrogram.png to healthy
# Copied: O041_spectrogram.png to healthy
# Copied: O006_spectrogram.png to healthy
# Copied: O033_spectrogram.png to healthy
# Copied: O017_spectrogram.png to healthy
# Copied: O046_spectrogram.png to healthy
# Copied: O058_spectrogram.png to healthy
# Copied: O022_spectrogram.png to healthy
# Copied: O082_spectrogram.png to healthy
# Copied: O008_spectrogram.png to healthy
# Copied: O084_spectrogram.png to healthy
# Copied: O064_spectrogram.png to healthy
# Copied: O051_spectrogram.png to healthy
# Copied: O066_spectrogram.png to healthy
# Copied: O032_spectrogram.png to healthy
# Copied: O085_spectrogram.png to healthy
# Copied: O023_spectrogram.png to healthy
# Copied: O024_spectrogram.png to healthy
# Copied: O019_spectrogram.png to healthy
# Copied: O016_spectrogram.png to healthy
# Copied: O087_spectrogram.png to healthy
# Copied: O047_spectrogram.png to healthy
# Copied: O021_spectrogram.png to healthy
# Copied: O063_spectrogram.png to healthy
# Copied: O094_spectrogram.png to healthy
# Copied: O035_spectrogram.png to healthy
# Copied: O011_spectrogram.png to healthy
# Copied: O093_spectrogram.png to healthy
# Copied: O056_spectrogram.png to healthy
# Copied: O100_spectrogram.png to healthy
# Copied: O072_spectrogram.png to healthy
# Copied: O040_spectrogram.png to healthy
# Copied: O057_spectrogram.png to healthy
# Copied: O073_spectrogram.png to healthy
# Copied: O007_spectrogram.png to healthy
# Copied: O092_spectrogram.png to healthy
# Copied: O034_spectrogram.png to healthy
# Copied: O010_spectrogram.png to healthy
# Copied: O048_spectrogram.png to healthy
# Copied: O009_spectrogram.png to healthy
# Copied: O075_spectrogram.png to healthy
# Copied: O059_spectrogram.png to healthy
# Copied: O065_spectrogram.png to healthy
# Copied: N006_spectrogram.png to pre-ictal
# Copied: N041_spectrogram.png to pre-ictal
# Copied: N009_spectrogram.png to pre-ictal
# Copied: N034_spectrogram.png to pre-ictal
# Copied: N092_spectrogram.png to pre-ictal
# Copied: N073_spectrogram.png to pre-ictal
# Copied: N050_spectrogram.png to pre-ictal
# Copied: N017_spectrogram.png to pre-ictal
# Copied: N010_spectrogram.png to pre-ictal
# Copied: N057_spectrogram.png to pre-ictal
# Copied: N074_spectrogram.png to pre-ictal
# Copied: N049_spectrogram.png to pre-ictal
# Copied: N001_spectrogram.png to pre-ictal
# Copied: N095_spectrogram.png to pre-ictal
# Copied: N018_spectrogram.png to pre-ictal
# Copied: N046_spectrogram.png to pre-ictal
# Copied: N033_spectrogram.png to pre-ictal
# Copied: N025_spectrogram.png to pre-ictal
# Copied: N062_spectrogram.png to pre-ictal
# Copied: N083_spectrogram.png to pre-ictal
# Copied: N088_spectrogram.png to pre-ictal
# Copied: N048_spectrogram.png to pre-ictal
# Copied: N024_spectrogram.png to pre-ictal
# Copied: N019_spectrogram.png to pre-ictal
# Copied: N082_spectrogram.png to pre-ictal
# Copied: N063_spectrogram.png to pre-ictal
# Copied: N047_spectrogram.png to pre-ictal
# Copied: N016_spectrogram.png to pre-ictal
# Copied: N051_spectrogram.png to pre-ictal
# Copied: N032_spectrogram.png to pre-ictal
# Copied: N075_spectrogram.png to pre-ictal
# Copied: N094_spectrogram.png to pre-ictal
# Copied: N023_spectrogram.png to pre-ictal
# Copied: N064_spectrogram.png to pre-ictal
# Copied: N085_spectrogram.png to pre-ictal
# Copied: N059_spectrogram.png to pre-ictal
# Copied: N040_spectrogram.png to pre-ictal
# Copied: N100_spectrogram.png to pre-ictal
# Copied: N037_spectrogram.png to pre-ictal
# Copied: N091_spectrogram.png to pre-ictal
# Copied: N007_spectrogram.png to pre-ictal
# Copied: N072_spectrogram.png to pre-ictal
# Copied: N065_spectrogram.png to pre-ictal
# Copied: N035_spectrogram.png to pre-ictal
# Copied: N008_spectrogram.png to pre-ictal
# Copied: N022_spectrogram.png to pre-ictal
# Copied: N058_spectrogram.png to pre-ictal
# Copied: N011_spectrogram.png to pre-ictal
# Copied: N056_spectrogram.png to pre-ictal
# Copied: N093_spectrogram.png to pre-ictal
# Copied: N084_spectrogram.png to pre-ictal
# Copied: N004_spectrogram.png to pre-ictal
# Copied: N039_spectrogram.png to pre-ictal
# Copied: N043_spectrogram.png to pre-ictal
# Copied: N067_spectrogram.png to pre-ictal
# Copied: N086_spectrogram.png to pre-ictal
# Copied: N020_spectrogram.png to pre-ictal
# Copied: N055_spectrogram.png to pre-ictal
# Copied: N012_spectrogram.png to pre-ictal
# Copied: N089_spectrogram.png to pre-ictal
# Copied: N096_spectrogram.png to pre-ictal
# Copied: N044_spectrogram.png to pre-ictal
# Copied: N030_spectrogram.png to pre-ictal
# Copied: N098_spectrogram.png to pre-ictal
# Copied: N053_spectrogram.png to pre-ictal
# Copied: N079_spectrogram.png to pre-ictal
# Copied: N077_spectrogram.png to pre-ictal
# Copied: N003_spectrogram.png to pre-ictal
# Copied: N076_spectrogram.png to pre-ictal
# Copied: N052_spectrogram.png to pre-ictal
# Copied: N027_spectrogram.png to pre-ictal
# Copied: N097_spectrogram.png to pre-ictal
# Copied: N071_spectrogram.png to pre-ictal
# Copied: N031_spectrogram.png to pre-ictal
# Copied: N028_spectrogram.png to pre-ictal
# Copied: N081_spectrogram.png to pre-ictal
# Copied: N014_spectrogram.png to pre-ictal
# Copied: N036_spectrogram.png to pre-ictal
# Copied: N060_spectrogram.png to pre-ictal
# Copied: N026_spectrogram.png to pre-ictal
# Copied: N061_spectrogram.png to pre-ictal
# Copied: N029_spectrogram.png to pre-ictal
# Copied: N015_spectrogram.png to pre-ictal
# Copied: N090_spectrogram.png to pre-ictal
# Copied: N068_spectrogram.png to pre-ictal
# Copied: N045_spectrogram.png to pre-ictal
# Copied: N042_spectrogram.png to pre-ictal
# Copied: N080_spectrogram.png to pre-ictal
# Copied: N078_spectrogram.png to pre-ictal
# Copied: N099_spectrogram.png to pre-ictal
# Copied: N066_spectrogram.png to pre-ictal
# Copied: N013_spectrogram.png to pre-ictal
# Copied: N087_spectrogram.png to pre-ictal
# Copied: N021_spectrogram.png to pre-ictal
# Copied: N038_spectrogram.png to pre-ictal
# Copied: N054_spectrogram.png to pre-ictal
# Copied: N069_spectrogram.png to pre-ictal
# Copied: N070_spectrogram.png to pre-ictal
# Copied: N002_spectrogram.png to pre-ictal
# Copied: N005_spectrogram.png to pre-ictal
# Copied: F100_spectrogram.png to pre-ictal
# Copied: F072_spectrogram.png to pre-ictal
# Copied: F093_spectrogram.png to pre-ictal
# Copied: F016_spectrogram.png to pre-ictal
# Copied: F059_spectrogram.png to pre-ictal
# Copied: F051_spectrogram.png to pre-ictal
# Copied: F007_spectrogram.png to pre-ictal
# Copied: F040_spectrogram.png to pre-ictal
# Copied: F024_spectrogram.png to pre-ictal
# Copied: F082_spectrogram.png to pre-ictal
# Copied: F063_spectrogram.png to pre-ictal
# Copied: F019_spectrogram.png to pre-ictal
# Copied: F047_spectrogram.png to pre-ictal
# Copied: F008_spectrogram.png to pre-ictal
# Copied: F011_spectrogram.png to pre-ictal
# Copied: F056_spectrogram.png to pre-ictal
# Copied: F023_spectrogram.png to pre-ictal
# Copied: F035_spectrogram.png to pre-ictal
# Copied: F064_spectrogram.png to pre-ictal
# Copied: F085_spectrogram.png to pre-ictal
# Copied: F075_spectrogram (1).png to pre-ictal
# Copied: F048_spectrogram (1).png to pre-ictal
# Copied: F094_spectrogram (1).png to pre-ictal
# Copied: F046_spectrogram (1).png to pre-ictal
# Copied: F018_spectrogram (1).png to pre-ictal
# Copied: F025_spectrogram (1).png to pre-ictal
# Copied: F083_spectrogram (1).png to pre-ictal
# Copied: F083_spectrogram.png to pre-ictal
# Copied: F025_spectrogram.png to pre-ictal
# Copied: F001_spectrogram (1).png to pre-ictal
# Copied: F018_spectrogram.png to pre-ictal
# Copied: F046_spectrogram.png to pre-ictal
# Copied: F062_spectrogram (1).png to pre-ictal
# Copied: F001_spectrogram.png to pre-ictal
# Copied: F062_spectrogram.png to pre-ictal
# Copied: F094_spectrogram.png to pre-ictal
# Copied: F075_spectrogram.png to pre-ictal
# Copied: F032_spectrogram.png to pre-ictal
# Copied: F048_spectrogram.png to pre-ictal
# Copied: F058_spectrogram.png to pre-ictal
# Copied: F065_spectrogram.png to pre-ictal
# Copied: F022_spectrogram.png to pre-ictal
# Copied: F084_spectrogram.png to pre-ictal
# Copied: F010_spectrogram.png to pre-ictal
# Copied: F095_spectrogram.png to pre-ictal
# Copied: F009_spectrogram.png to pre-ictal
# Copied: F092_spectrogram.png to pre-ictal
# Copied: F034_spectrogram.png to pre-ictal
# Copied: F074_spectrogram.png to pre-ictal
# Copied: F049_spectrogram.png to pre-ictal
# Copied: F050_spectrogram.png to pre-ictal
# Copied: F057_spectrogram.png to pre-ictal
# Copied: F017_spectrogram.png to pre-ictal
# Copied: F032_spectrogram (1).png to pre-ictal
# Copied: F033_spectrogram.png to pre-ictal
# Copied: F073_spectrogram.png to pre-ictal
# Copied: F028_spectrogram.png to pre-ictal
# Copied: F055_spectrogram.png to pre-ictal
# Copied: F052_spectrogram.png to pre-ictal
# Copied: F015_spectrogram.png to pre-ictal
# Copied: F012_spectrogram.png to pre-ictal
# Copied: F068_spectrogram.png to pre-ictal
# Copied: F076_spectrogram.png to pre-ictal
# Copied: F003_spectrogram.png to pre-ictal
# Copied: F097_spectrogram.png to pre-ictal
# Copied: F044_spectrogram.png to pre-ictal
# Copied: F081_spectrogram.png to pre-ictal
# Copied: F031_spectrogram.png to pre-ictal
# Copied: F079_spectrogram.png to pre-ictal
# Copied: F041_spectrogram.png to pre-ictal
# Copied: F027_spectrogram.png to pre-ictal
# Copied: F006_spectrogram.png to pre-ictal
# Copied: F060_spectrogram.png to pre-ictal
# Copied: F098_spectrogram.png to pre-ictal
# Copied: F037_spectrogram.png to pre-ictal
# Copied: F014_spectrogram.png to pre-ictal
# Copied: F005_spectrogram.png to pre-ictal
# Copied: F091_spectrogram.png to pre-ictal
# Copied: F087_spectrogram.png to pre-ictal
# Copied: F042_spectrogram.png to pre-ictal
# Copied: F038_spectrogram.png to pre-ictal
# Copied: F070_spectrogram.png to pre-ictal
# Copied: F054_spectrogram.png to pre-ictal
# Copied: F069_spectrogram.png to pre-ictal
# Copied: F078_spectrogram.png to pre-ictal
# Copied: F077_spectrogram.png to pre-ictal
# Copied: F096_spectrogram.png to pre-ictal
# Copied: F045_spectrogram.png to pre-ictal
# Copied: F021_spectrogram.png to pre-ictal
# Copied: F030_spectrogram.png to pre-ictal
# Copied: F080_spectrogram.png to pre-ictal
# Copied: F099_spectrogram.png to pre-ictal
# Copied: F026_spectrogram.png to pre-ictal
# Copied: F002_spectrogram.png to pre-ictal
# Copied: F066_spectrogram.png to pre-ictal
# Copied: F053_spectrogram.png to pre-ictal
# Copied: F029_spectrogram.png to pre-ictal
# Copied: F061_spectrogram.png to pre-ictal
# Copied: F071_spectrogram.png to pre-ictal
# Copied: F036_spectrogram.png to pre-ictal
# Copied: F090_spectrogram.png to pre-ictal
# Copied: F086_spectrogram.png to pre-ictal
# Copied: F004_spectrogram.png to pre-ictal
# Copied: F043_spectrogram.png to pre-ictal
# Copied: F039_spectrogram.png to pre-ictal
# Copied: F067_spectrogram.png to pre-ictal
# Copied: F020_spectrogram.png to pre-ictal
# Copied: F089_spectrogram.png to pre-ictal
# Copied: F088_spectrogram.png to pre-ictal
# Copied: F013_spectrogram.png to pre-ictal
# Copied: S081_spectrogram.png to epilepsy
# Copied: S076_spectrogram.png to epilepsy
# Copied: S002_spectrogram.png to epilepsy
# Copied: S080_spectrogram.png to epilepsy
# Copied: S045_spectrogram.png to epilepsy
# Copied: S053_spectrogram.png to epilepsy
# Copied: S014_spectrogram.png to epilepsy
# Copied: S029_spectrogram.png to epilepsy
# Copied: S026_spectrogram.png to epilepsy
# Copied: S070_spectrogram.png to epilepsy
# Copied: S096_spectrogram.png to epilepsy
# Copied: S077_spectrogram.png to epilepsy
# Copied: S078_spectrogram.png to epilepsy
# Copied: S054_spectrogram.png to epilepsy
# Copied: S005_spectrogram.png to epilepsy
# Copied: S087_spectrogram.png to epilepsy
# Copied: S069_spectrogram.png to epilepsy
# Copied: S038_spectrogram.png to epilepsy
# Copied: S042_spectrogram.png to epilepsy
# Copied: S021_spectrogram.png to epilepsy
# Copied: S066_spectrogram.png to epilepsy
# Copied: S061_spectrogram.png to epilepsy
# Copied: S013_spectrogram.png to epilepsy
# Copied: S037_spectrogram.png to epilepsy
# Copied: S091_spectrogram.png to epilepsy
# Copied: S088_spectrogram.png to epilepsy
# Copied: S030_spectrogram.png to epilepsy
# Copied: S071_spectrogram.png to epilepsy
# Copied: S055_spectrogram.png to epilepsy
# Copied: S012_spectrogram.png to epilepsy
# Copied: S039_spectrogram.png to epilepsy
# Copied: S086_spectrogram.png to epilepsy
# Copied: S020_spectrogram.png to epilepsy
# Copied: S043_spectrogram.png to epilepsy
# Copied: S079_spectrogram.png to epilepsy
# Copied: S044_spectrogram.png to epilepsy
# Copied: S089_spectrogram.png to epilepsy
# Copied: S068_spectrogram.png to epilepsy
# Copied: S067_spectrogram.png to epilepsy
# Copied: S004_spectrogram.png to epilepsy
# Copied: S036_spectrogram.png to epilepsy
# Copied: S099_spectrogram.png to epilepsy
# Copied: S015_spectrogram.png to epilepsy
# Copied: S052_spectrogram.png to epilepsy
# Copied: S097_spectrogram.png to epilepsy
# Copied: S031_spectrogram.png to epilepsy
# Copied: S060_spectrogram.png to epilepsy
# Copied: S028_spectrogram.png to epilepsy
# Copied: S003_spectrogram.png to epilepsy
# Copied: S098_spectrogram.png to epilepsy
# Copied: S027_spectrogram.png to epilepsy
# Copied: S001_spectrogram.png to epilepsy
# Copied: S046_spectrogram.png to epilepsy
# Copied: S049_spectrogram.png to epilepsy
# Copied: S062_spectrogram.png to epilepsy
# Copied: S033_spectrogram.png to epilepsy
# Copied: S050_spectrogram.png to epilepsy
# Copied: S017_spectrogram.png to epilepsy
# Copied: S074_spectrogram.png to epilepsy
# Copied: S095_spectrogram.png to epilepsy
# Copied: S090_spectrogram.png to epilepsy
# Copied: S009_spectrogram.png to epilepsy
# Copied: S073_spectrogram.png to epilepsy
# Copied: S006_spectrogram.png to epilepsy
# Copied: S092_spectrogram.png to epilepsy
# Copied: S084_spectrogram.png to epilepsy
# Copied: S065_spectrogram.png to epilepsy
# Copied: S041_spectrogram.png to epilepsy
# Copied: S083_spectrogram.png to epilepsy
# Copied: S018_spectrogram.png to epilepsy
# Copied: S022_spectrogram.png to epilepsy
# Copied: S025_spectrogram.png to epilepsy
# Copied: S058_spectrogram.png to epilepsy
# Copied: S024_spectrogram.png to epilepsy
# Copied: S063_spectrogram.png to epilepsy
# Copied: S094_spectrogram.png to epilepsy
# Copied: S082_spectrogram.png to epilepsy
# Copied: S047_spectrogram.png to epilepsy
# Copied: S019_spectrogram.png to epilepsy
# Copied: S032_spectrogram.png to epilepsy
# Copied: S048_spectrogram.png to epilepsy
# Copied: S051_spectrogram.png to epilepsy
# Copied: S072_spectrogram.png to epilepsy
# Copied: S016_spectrogram.png to epilepsy
# Copied: S011_spectrogram.png to epilepsy
# Copied: S056_spectrogram.png to epilepsy
# Copied: S008_spectrogram.png to epilepsy
# Copied: S093_spectrogram.png to epilepsy
# Copied: S035_spectrogram.png to epilepsy
# Copied: S075_spectrogram.png to epilepsy
# Copied: S100_spectrogram.png to epilepsy
# Copied: S040_spectrogram.png to epilepsy
# Copied: S007_spectrogram.png to epilepsy
# Copied: S006_spectrogram (1).png to epilepsy
# Copied: S034_spectrogram.png to epilepsy
# Copied: S059_spectrogram.png to epilepsy
# Copied: S009_spectrogram (1).png to epilepsy
# Copied: S073_spectrogram (1).png to epilepsy
# Copied: S057_spectrogram.png to epilepsy
# Copied: S064_spectrogram.png to epilepsy
# Copied: S092_spectrogram (1).png to epilepsy
# Copied: S085_spectrogram.png to epilepsy
# Copied: S023_spectrogram.png to epilepsy
# Copied: S010_spectrogram.png to epilepsy
# Images merged into categories successfully.

# %%
import os
import random
import shutil
from sklearn.model_selection import train_test_split

main_directory = '/content/drive/MyDrive/Paper/Epileptic-Seizure-Detection-master/Images/Three-Classes/Merged'
image_folders = ['epilepsy', 'healthy', 'pre-ictal']

train_dir = os.path.join(main_directory, 'Train')
val_dir = os.path.join(main_directory, 'Validation')
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)


for folder in image_folders:
    folder_path = os.path.join(main_directory, folder)
    train_folder = os.path.join(train_dir, folder)
    val_folder = os.path.join(val_dir, folder)
    os.makedirs(train_folder, exist_ok=True)
    os.makedirs(val_folder, exist_ok=True)


    image_files = os.listdir(folder_path)
    random.shuffle(image_files) 

    train_files, val_files = train_test_split(image_files, test_size=0.2, random_state=42)

    for file in train_files:
        shutil.copy(os.path.join(folder_path, file), os.path.join(train_folder, file))

    for file in val_files:
        shutil.copy(os.path.join(folder_path, file), os.path.join(val_folder, file))

print("Dataset split into train and validation sets successfully.")
# Out:
# Dataset split into train and validation sets successfully.

# %% [markdown]
# Zeina Part:
#
# WRITE THE CODE FOR DCGAN after this comment:
# (Note: Generate synthetic data for the 3 classes and save each class in a separated folder)
